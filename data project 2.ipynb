# %% [markdown]
# [My github repository](https://github.com/Aimayasir/PF-project/blob/main/data%20project%202.ipynb)

# %%
import pandas as pd

# %% [markdown]
# # Data load

# %%
df= pd.read_csv("C:\\Users\\hassnain computer\\folder\\data .project.csv")

# %%
df.shape
# Out:
# (12713, 4)

# %% [markdown]
# # Data cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12713 entries, 0 to 12712
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   University   12713 non-null  object
#  1   Country      12713 non-null  object
#  2   City         12713 non-null  object
#  3   Global Rank  12713 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 397.4+ KB

# %%
#df = pd.DataFrame(df)

# %%
column = list(df.columns)
column
# Out:
# ['University', 'Country', 'City', 'Global Rank']

# %% [markdown]
# check empty N\A values

# %%
df.isna().sum()
# Out:
# University     0
# Country        0
# City           0
# Global Rank    0
# dtype: int64

# %% [markdown]
#  Cleaning an empty data set

# %%
df.dropna()
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# 2             6297
# 3             6411
# 4             6421
# ...            ...
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698
#
# [12713 rows x 4 columns]

# %%
df.dropna(inplace=True)

# %% [markdown]
# # Replace empty values

# %%
df.fillna(33)
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# 2             6297
# 3             6411
# 4             6421
# ...            ...
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698
#
# [12713 rows x 4 columns]

# %% [markdown]
# # Replace a specefic columns

# %%
df['Country'].fillna(999)
# Out:
# 0        Algeria
# 1        Algeria
# 2        Algeria
# 3        Algeria
# 4        Algeria
#           ...
# 12708    Uruguay
# 12709    Uruguay
# 12710    Uruguay
# 12711    Uruguay
# 12712    Uruguay
# Name: Country, Length: 12713, dtype: object

# %%
df['Global Rank'].mean() # take out average
# Out:
# 6369.518760324077

# %%
df['Global Rank'].mode()# most common
# Out:
# 0        320
# 1        780
# 2        937
# 3        977
# 4        985
#        ...
# 180    12678
# 181    12679
# 182    12680
# 183    12681
# 184    12682
# Name: Global Rank, Length: 185, dtype: int64

# %%
df['Global Rank'].median()# middle value
# Out:
# 6373.0

# %% [markdown]
# # Data duplications

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12708    False
# 12709    False
# 12710    False
# 12711    False
# 12712    False
# Length: 12713, dtype: bool

# %%
#pd.set_option("display.max_rows",None)
#pd.set_option("display.max_columns",None)
#df.duplicated()

# %%
df.drop_duplicates()
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# 2             6297
# 3             6411
# 4             6421
# ...            ...
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698
#
# [12529 rows x 4 columns]

# %%
df.describe()
# Out:
#         Global Rank
# count  12713.000000
# mean    6369.518760
# std     3665.469943
# min        1.000000
# 25%     3199.000000
# 50%     6373.000000
# 75%     9540.000000
# max    12721.000000

# %%
df.describe(include="all").iloc[[0,10,]]# fetch data from index or position
# Out:
#       University Country   City  Global Rank
# count      12713   12713  12713      12713.0
# max          NaN     NaN    NaN      12721.0

# %%
df.describe(include="all").loc[["min","max"]]#fetch data from values of list
# Out:
#     University Country City  Global Rank
# min        NaN     NaN  NaN          1.0
# max        NaN     NaN  NaN      12721.0

# %% [markdown]
# # Adding a new column in data frame

# %%
df['col']=5
df
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank  col
# 0             3677    5
# 1             4919    5
# 2             6297    5
# 3             6411    5
# 4             6421    5
# ...            ...  ...
# 12708        11518    5
# 12709        11549    5
# 12710        11572    5
# 12711        11630    5
# 12712        12698    5
#
# [12713 rows x 5 columns]

# %% [markdown]
# # Remove a column

# %%
df.drop(columns=['col'],inplace=True)
df
# Out:
#                                               University  Country     City  \
# 0      Université des Sciences et de la Technologie H...  Algeria  Algiers
# 1               Université Benyoucef Benkhedda d’Alger 1  Algeria  Algiers
# 2              École Nationale Supérieure d’Informatique  Algeria  Algiers
# 3                          École Nationale Polytechnique  Algeria  Algiers
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algeria  Algiers
# ...                                                  ...      ...      ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay  Uruguay
# 12709                      Politécnico de Punta del Este  Uruguay  Uruguay
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay  Uruguay
# 12711          Instituto Metodista Universitario Crandon  Uruguay  Uruguay
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay  Uruguay
#
#        Global Rank
# 0             3677
# 1             4919
# 2             6297
# 3             6411
# 4             6421
# ...            ...
# 12708        11518
# 12709        11549
# 12710        11572
# 12711        11630
# 12712        12698
#
# [12713 rows x 4 columns]

# %% [markdown]
# # Adding a row

# %%
a=pd.DataFrame({' University':100,
                'Country':'Pakistan',
                  'city':'Lahore'},
                  index=[0])
a
df=pd.concat([a,df])
df
# Out:
#         University   Country    city  \
# 0            100.0  Pakistan  Lahore
# 0              NaN   Algeria     NaN
# 1              NaN   Algeria     NaN
# 2              NaN   Algeria     NaN
# 3              NaN   Algeria     NaN
# ...            ...       ...     ...
# 12708          NaN   Uruguay     NaN
# 12709          NaN   Uruguay     NaN
# 12710          NaN   Uruguay     NaN
# 12711          NaN   Uruguay     NaN
# 12712          NaN   Uruguay     NaN
#
#                                               University     City  Global Rank
# 0                                                    NaN      NaN          NaN
# 0      Université des Sciences et de la Technologie H...  Algiers       3677.0
# 1               Université Benyoucef Benkhedda d’Alger 1  Algiers       4919.0
# 2              École Nationale Supérieure d’Informatique  Algiers       6297.0
# 3                          École Nationale Polytechnique  Algiers       6411.0
# ...                                                  ...      ...          ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay      11518.0
# 12709                      Politécnico de Punta del Este  Uruguay      11549.0
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay      11572.0
# 12711          Instituto Metodista Universitario Crandon  Uruguay      11630.0
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay      12698.0
#
# [12714 rows x 6 columns]

# %% [markdown]
# # Remove a row

# %%
df.drop(0,inplace=True)
df
# Out:
#         University  Country city  \
# 1              NaN  Algeria  NaN
# 2              NaN  Algeria  NaN
# 3              NaN  Algeria  NaN
# 4              NaN  Algeria  NaN
# 5              NaN  Algeria  NaN
# ...            ...      ...  ...
# 12708          NaN  Uruguay  NaN
# 12709          NaN  Uruguay  NaN
# 12710          NaN  Uruguay  NaN
# 12711          NaN  Uruguay  NaN
# 12712          NaN  Uruguay  NaN
#
#                                               University     City  Global Rank
# 1               Université Benyoucef Benkhedda d’Alger 1  Algiers       4919.0
# 2              École Nationale Supérieure d’Informatique  Algiers       6297.0
# 3                          École Nationale Polytechnique  Algiers       6411.0
# 4           Université Abou el Kacem Saâdallah d’Alger 2  Algiers       6421.0
# 5           Université Brahim Soltane Chaibout d’Alger 3  Algiers       6746.0
# ...                                                  ...      ...          ...
# 12708  Facultad de Teologa del Uruguay Mons. Mariano ...  Uruguay      11518.0
# 12709                      Politécnico de Punta del Este  Uruguay      11549.0
# 12710  Instituto Universitario de Docencia, Investiga...  Uruguay      11572.0
# 12711          Instituto Metodista Universitario Crandon  Uruguay      11630.0
# 12712  Instituto Universitario de Postgrado en Psicoa...  Uruguay      12698.0
#
# [12712 rows x 6 columns]

# %% [markdown]
# # Slicing in code

# %%
df[3:6]
# Out:
#     University  Country city                                    University  \
# 4          NaN  Algeria  NaN  Université Abou el Kacem Saâdallah d’Alger 2
# 5          NaN  Algeria  NaN  Université Brahim Soltane Chaibout d’Alger 3
# 6          NaN  Algeria  NaN        École Nationale Supérieure Agronomique
#
#       City  Global Rank
# 4  Algiers       6421.0
# 5  Algiers       6746.0
# 6  Algiers       7790.0

# %%
df[3:5:2]
# Out:
#     University  Country city                                    University  \
# 4          NaN  Algeria  NaN  Université Abou el Kacem Saâdallah d’Alger 2
#
#       City  Global Rank
# 4  Algiers       6421.0

# %%
df[['Country']][45:56]
# Out:
#     Country
# 46  Algeria
# 47  Algeria
# 48  Algeria
# 49  Algeria
# 50  Algeria
# 51  Algeria
# 52  Algeria
# 53  Algeria
# 54  Algeria
# 55  Algeria
# 56  Algeria

# %% [markdown]
# # Flow charts

# %%
df['Country'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df['Country'].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Country'>

# %%
df['Country'].value_counts().plot(kind="box")
# Out:
# <Axes: >

# %%
df['Country'].value_counts().plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Country'].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['Country'].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Country'>

# %%
df['Country'].value_counts().plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
df['Country'].value_counts().plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Data aggregation

# %%
df.aggregate(['sum', 'min'])
# Out:
#       University                                            Country  city  \
# sum          0.0  AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...   0.0
# min          NaN                                        Afghanistan   NaN
#
#                                             University  \
# sum  Université Benyoucef Benkhedda d’Alger 1École ...
# min                              A.T. Still University
#
#                                                   City  Global Rank
# sum  AlgiersAlgiersAlgiersAlgiersAlgiersAlgiersAlgi...   80972015.0
# min                                               Abia          1.0

# %% [markdown]
#  sum values()

# %%
df['Global Rank'].sum()
# Out:
# 80972015.0

# %% [markdown]
# ##  std() – Standard Deviation

# %%
df['Global Rank'].std()
# Out:
# 3665.5363213995515

# %% [markdown]
# ## var() – Variance Calculation
# Computes the variance of a numerical column.

# %%
df['Global Rank'].var()
# Out:
# 13436156.523499357

# %% [markdown]
# ## data preprocessing

# %%
df.isnull().sum()
# Out:
#  University    12712
# Country            0
# city           12712
# University         0
# City               0
# Global Rank        0
# dtype: int64

# %% [markdown]
# ## rename() – Rename columns
# Renames column names for better understanding.

# %%
df.rename(columns={'University': 'Uni'}, inplace=True)

# %% [markdown]
# #  Data Saving

# %%
df = pd.read_csv("data .project.csv")
df
df.to_excel("newdata.xlsx", sheet_name="newsheet")
